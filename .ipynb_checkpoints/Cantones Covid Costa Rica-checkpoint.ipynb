# %%
import pandas as pd

# %%
activos = pd.read_csv('datos/07_29_CSV_ACTIVOS.csv', encoding='iso-8859-1')
activos.head([])
# Out:
#    cod_provin provincia  cod_canton        canton  21/04/2020  22/04/2020  \
# 0           1  San Jos         112        Acosta           0           0
# 1           1  San Jos         110    Alajuelita          12          11
# 2           1  San Jos         106        Aserr          11          10
# 3           1  San Jos         118    Curridabat          19          19
# 4           1  San Jos         103  Desamparados          45          42
#
#    23/04/2020  24/04/2020  25/04/2020  26/04/2020  ...  20/07/2020  \
# 0           0           0           0           0  ...          31
# 1          11          11          11          11  ...         645
# 2          10          10          11          10  ...          85
# 3          17          17          16          15  ...         183
# 4          43          41          37          34  ...         692
#
#    21/07/2020  22/07/2020  23/07/2020  24/07/2020  25/07/2020  26/07/2020  \
# 0          26          22          28          28          32          32
# 1         646         687         765         801         884         908
# 2          86          81         101         104         119         119
# 3         192         210         231         241         256         264
# 4         706         729         801         841         916         924
#
#    27/07/2020  28/07/2020  29/07/2020
# 0          29          30          29
# 1         941         978        1006
# 2         132         143         146
# 3         270         273         291
# 4         974        1011        1043
#
# [5 rows x 104 columns]

# %%
activos_alajuela = activos[activos["provincia"]=='Alajuela']
activos_alajuela
# Out:
#     cod_provin provincia  cod_canton      canton  21/04/2020  22/04/2020  \
# 20           2  Alajuela         201    Alajuela          37          31
# 21           2  Alajuela         205      Atenas           2           3
# 22           2  Alajuela         203      Grecia          14          14
# 23           2  Alajuela         215     Guatuso           0           0
# 24           2  Alajuela         214  Los Chiles           0           0
# 25           2  Alajuela         206     Naranjo           4           4
# 26           2  Alajuela         209     Orotina           6           6
# 27           2  Alajuela         207    Palmares          11          10
# 28           2  Alajuela         208        Pos           5           5
# 29           2  Alajuela         216  Ro Cuarto           0           0
# 30           2  Alajuela         210  San Carlos          24          22
# 31           2  Alajuela         204   San Mateo           0           0
# 32           2  Alajuela         202   San Ramn          10          10
# 33           2  Alajuela         212      Sarch           5           5
# 34           2  Alajuela         213       Upala           0           0
# 35           2  Alajuela         211     Zarcero           0           0
#
#     23/04/2020  24/04/2020  25/04/2020  26/04/2020  ...  20/07/2020  \
# 20          31          31          30          27  ...         610
# 21           4           4           4           4  ...          29
# 22          14          14          14          13  ...          48
# 23           0           0           0           0  ...          40
# 24           0           0           0           0  ...          49
# 25           4           1           1           1  ...          42
# 26           3           3           3           3  ...           2
# 27           9           5           4           3  ...          25
# 28           5           5           4           3  ...          33
# 29           0           0           0           0  ...           4
# 30          22          22          21          20  ...         118
# 31           0           0           0           0  ...           2
# 32          10          10          10          10  ...          69
# 33           5           5           5           3  ...          13
# 34           0           0           0           0  ...          31
# 35           0           0           0           0  ...           3
#
#     21/07/2020  22/07/2020  23/07/2020  24/07/2020  25/07/2020  26/07/2020  \
# 20         621         643         662         700         734         799
# 21          29          32          34          37          38          41
# 22          53          59          63          64          65          69
# 23          27          26          19          21          17          19
# 24          49          40          36          37          37          40
# 25          45          50          52          53          55          65
# 26           1           1           1           2           3           3
# 27          26          26          24          25          23          24
# 28          34          36          35          37          36          39
# 29           4           4           4           5           6           6
# 30         107         116         124         130         120         128
# 31           2           2           0           0           0           0
# 32          70          71          56          57          48          57
# 33          13          18          17          19          20          21
# 34          29          22          22          20          20          20
# 35           3           8          10           9           8           8
#
#     27/07/2020  28/07/2020  29/07/2020
# 20         828         862         918
# 21          42          43          34
# 22          69          69          70
# 23          19          20          20
# 24          45          45          43
# 25          73          74          75
# 26           3           3           4
# 27          18          20          21
# 28          42          44          37
# 29           6           6           7
# 30         144         155         154
# 31           0           0           0
# 32          58          61          63
# 33          23          23          23
# 34          14          13           6
# 35           8           8           8
#
# [16 rows x 104 columns]

# %%
def filterandplot(ds, codCanton):
    activos_canton = ds[ds["cod_canton"==codCanton]]
    transposed = activos_canton.melt(id_vars=activos_canton.columns[0:4])
    transposed.head()
    transposed.plot.line(x="variable", y="value")
    return activos_canton

# %%
cod_poas = 208
cod_grecia = 203
activos_poas= filterandplot(activos_alajuela, cod_poas)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-c1a9bfbaa320> in <module>
#       1 cod_poas = "208"
#       2 cod_grecia = 203
# ----> 3 activos_poas= filterandplot(activos_alajuela, cod_poas)
#
# <ipython-input-60-e8754cbb0f33> in filterandplot(ds, codCanton)
#       1 def filterandplot(ds, codCanton):
# ----> 2     activos_canton = ds[ds["cod_canton"==codCanton]]
#       3     transposed = activos_canton.melt(id_vars=activos_canton.columns[0:4])
#       4     transposed.head()
#       5     transposed.plot.line(x="variable", y="value")
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
